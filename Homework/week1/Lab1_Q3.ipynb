# %% [markdown]
# ---
# # จงเขียนโปรแกรมที่รับชื่อและอายุจากผู้ใช้ แล้วคำนวณปีเกิดของผู้ใช้และแสดงผลลัพธ์ดังตัวอย่างข้างล่างนี้

# %% [markdown]
# ### ตัวอย่างการรัน:
#
# Name, age: Somsak 19 <br>
# Somsak's year of birth is 2549.

# %% [markdown]
# ##### ตัวอย่างการรัน:
#
# Name, age: Bella 2 <br>
# Bella's year of birth is 2566.

# %%
name,age = input("Please Enter Your Name and Age: ").split()
# Out:
# Please Enter Your Name and Age: Somsak 19

# %%
print(f"Name, age: {name} {age}")
print(f"{name}'s year of birth is {2568-int(age)}.")
# Out:
# Name, age: Somsak 19
# Somsak's year of birth is 2549.
