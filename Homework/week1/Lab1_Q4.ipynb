# %% [markdown]
# ---
# # จงเขียนโปรแกรมที่รับชื่อและอายุจากผู้ใช้ แล้วคำนวณปีเกิดของผู้ใช้เพื่อสร้าง email address ของผู้ใช้โดยเอาชื่อมาต่อด้วยเลข 2 หลักหลังของปีเกิดและต่อด้วย @rumail.ru.ac.th แสดงผลลัพธ์ดังตัวอย่างข้างล่างนี้

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Name: Somsak <br>
# Age : 20 <br>
# Somsak48@rumail.ru.ac.th

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Name: Jaidee <br>
# Age : 65 <br>
# Jaidee03@rumail.ru.ac.th

# %%
name,age = input("Please Enter Your Name and Age: ").split()
year = 2568 - int(age)
# Out:
# Please Enter Your Name and Age: Somsak 20

# %%
print("Name:"+name)
print("Age:"+age)
print(f"{name}{year%100}@rumail.ru.ac.th")
# Out:
# Name:Somsak
# Age:20
# Somsak48@rumail.ru.ac.th
