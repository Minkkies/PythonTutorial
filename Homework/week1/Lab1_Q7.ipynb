# %% [markdown]
# ---
# #จงเขียนโปรแกรมที่รับความยาวด้าน 3 ด้านของสามเหลี่ยมจากผู้ใช้ แล้วตรวจสอบว่าเป็นด้านของสามเหลี่ยม มุมฉากหรือไม่ และแสดงผลลัพธ์ดังตัวอย่างข้างล่างนี้

# %% [markdown]
# ตัวอย่างการทำงาน: <br>
# Length of 3 sides: 3,5,4<br>
# Right triangle: True

# %% [markdown]
# ตัวอย่างการทำงาน: <br>
# Length of 3 sides: 3.4,5,4 <br>
# Right triangle: False

# %%
import math
a, b, c = input('Length of 3 sides: ').split(',')
a, b, c = sorted([a, b, c])

print('Right triangle:' , float(c)**2 == float(a)**2 + float(b)**2)
# Out:
# Length of 3 sides: 3,4,5
# Right triangle: True
