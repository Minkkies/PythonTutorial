# %% [markdown]
# ---
# ## จงเขียนโปรแกรมที่รับราคาสินค้าและค่าขนส่งจากผู้ใช้ แล้วคำนวณยอดรวมที่ลูกค้าต้องจ่าย แล้วแสดง ผลลัพธ์ดังตัวอย่างข้างล่างนี้

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Price : 235.50 <br>
# Shipping :  30 <br>
# Total: 265.5 Baht (30.0 Baht shipping fee)

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Price : 1000 <br>
# Shipping :  45.5 <br>
# Total: 1045.5 Baht (45.5 Baht shipping fee)

# %%
price = float(input("Please Enter Product Price: " ))#แปลงเป็น float เพราะค่าเริ่มต้นที่รับเป็น string
shipping = float(input("Please Enter Shipping Fee: "))
total = price+shipping
# Out:
# Please Enter Product Price: 1000
# Please Enter Shipping Fee: 45.5

# %%
print(f"Price: {price} bath ")
print(f"Shipping Fee: {shipping} bath")
print(f"Total: {price+shipping} bath")
# Out:
# Price: 1000.0 bath
# Shipping Fee: 45.5 bath
# Total: 1045.5 bath
