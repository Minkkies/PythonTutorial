# %% [markdown]
# ---
# # จงเขียนโปรแกรมที่หาว่าสามารถหาผลเฉลยของสมการกำลังสองจากสูตร $𝑥 = −𝑏±\sqrt{b^2-4ac}$ ได้หรือไม่โดยตรวจสอบว่า $𝑏^2 − 4𝑎𝑐 ≥ 0$ และ $𝑎 ≠ 0$ แล้วแสดงผลลัพธ์ดังตัวอย่างข้างล่างนี้

# %% [markdown]
# ตัวอย่างการทำงาน: <br>
# Enter coefficients a, b, c : 1,4,3<br>
# Can use quadratic formula: True

# %% [markdown]
# ตัวอย่างการทำงาน: <br>
# Enter coefficients a, b, c : 2.3,-1.5,1.5 <br>
# Can use quadratic formula: False

# %%
import math

a, b, c = input('Enter coefficients a, b, c : ').split(",")
print('Can use quadratic formula:', (float(b)**2 - 4*float(a)*float(c) >= 0) and (float(b)**2 - 4*float(a)*float(c) != 0))
# Out:
# Enter coefficients a, b, c : 2.3,-1.5,1.5
# Can use quadratic formula: False
