# %% [markdown]
# # Q5 จงเขียนโปรแกรมที่รับคำมาต่อกันเป็นประโยค โดยจะหยุดรับเมื่อรับ . มา

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Next word : **.** <br>
# Sentence:

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Next word : **Bye** <br>
# Next word : **bye** <br>
# Next word : **.** <br>
# Sentence: Bye bye

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Next word : **My** <br>
# Next word : **name** <br>
# Next word : **is** <br>
# Next word : **next** <br>
# Next word : **word** <br>
# Next word : **.** <br>
# Sentence: My name is next word

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Next word : **My** <br>
# Next word : **name** <br>
# Next word : **is** <br>
# Next word : **Chicky** <br>
# Next word : **Chicky!** <br>
# Next word : **.** <br>
# Sentence: My name is Chicky Chicky!

# %%
word =''
sentence =''

while word != '.':
  word = input("Next word :")
  if word != '.' : sentence += word +' '

print(f"Sentence: {sentence.strip()}")
# Out:
# Next word :bye
# Next word :bye
# Next word :.
# Sentence: bye bye
