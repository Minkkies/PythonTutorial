# %% [markdown]
# # Q7 จงเขียนโปรแกรมที่วนรับอุณหภูมิสูงสุดของแต่ละวันในหนึ่งสัปดาห์ แล้วแสดงว่าวันใดมีอุณหภูมิลดลงจากวันก่อนหน้า

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Day 1 : **32.6** <br>
# Day 2 : **34.4** <br>
# Day 3 : **35.0** <br>
# Day 4 : **34.6** <br>
# Temperature dropped on day 4 <br>
# Day 5 : **35.0** <br>
# Day 6 : **35.6** <br>
# Day 7 : **36** <br>

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Day 1 : **32.6** <br>
# Day 2 : **34.4** <br>
# Day 3 : **35.0** <br>
# Day 4 : **34.6** <br>
# Temperature dropped on day 4 <br>
# Day 5 : **35.2** <br>
# Day 6 : **35.6** <br>
# Day 7 : **34** <br>
# Temperature dropped on day 7

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Day 1 : **32.6** <br>
# Day 2 : **34.4** <br>
# Day 3 : **35.0** <br>
# Day 4 : **34.6** <br>
# Temperature dropped on day 4 <br>
# Day 5 : **34.0** <br>
# Temperature dropped on day 5 <br>
# Day 6 : **35.6** <br>
# Day 7 : **34** <br>
# Temperature dropped on day 7

# %%
temp_1 = float(input(f'Day 1: '))

for i in range(2,8):
  temp = float(input(f'Day {i}: '))

  if temp_1 > temp:
    print(f'Temperature dropped on day {i}')

  temp_1 = temp
# Out:
# Day 1: 32.6
# Day 2: 34.4
# Day 3: 35.0
# Day 4: 34.6
# Temperature dropped on day 4
# Day 5: 34
# Temperature dropped on day 5
# Day 6: 35.6
# Day 7: 34
# Temperature dropped on day 7
