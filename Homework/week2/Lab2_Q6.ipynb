# %% [markdown]
# # Q6 จงเขียนโปรแกรมที่รับจำนวนเต็มบวก n แล้วหาจำนวนเต็มบวกที่หาร n ลงตัว

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Enter an integer : **12** <br>
# 12 is divisible by: <br>
# 1 <br>
# 2 <br>
# 3 <br>
# 4 <br>
# 6 <br>
# 12 <br>

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Enter an integer : **65** <br>
# 65 is divisible by: <br>
# 1 <br>
# 5 <br>
# 13 <br>
# 65 <br>

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Enter an integer : **211** <br>
# 211 is divisible by: <br>
# 1 <br>
# 211 <br>

# %%
integer = int(input("Enter an integer :"))
print(f"{integer} is divisible by:")
for i in range(1,integer + 1):
  if integer % i == 0 : print(i)
# Out:
# Enter an integer :65
# 65 is divisible by:
# 1
# 5
# 13
# 65
