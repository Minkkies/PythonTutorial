# %% [markdown]
# # Q1 จงเขียนโปรแกรมที่วนรับชื่อผู้ใช้จนกว่าจะเป็น Lisa

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Enter username : **Lisa** <br>
# Hello, Lisa

# %% [markdown]
# ### ตัวอย่างการทำงาน:
#
# Enter username : **test** <br>
# Incorrect. Enter again : **1234** <br>
# Incorrect. Enter again : **Jackson** <br>
# Incorrect. Enter again : **lisa** <br>
# Incorrect. Enter again : **Lisa** <br>
# Hello, Lisa

# %%
username = input("Enter username : ")
while username !='Lisa':
  username = input("Incorrect. Enter again : ")
print(f"Hello, {username}")
# Out:
# Enter username : test
# Incorrect. Enter again : 12345
# Incorrect. Enter again : Lisa
# Hello, Lisa

# %%
while True:
  username = input("Please enter your Username: ")

  if username == 'Lisa':
    print(f"Hello, {username}")
    break
  else:
    username = input("Incorrect. Enter again : ")
# Out:
# Please enter your Username: test
# Incorrect. Enter again : 1234
# Please enter your Username: Jackson
# Incorrect. Enter again : lisa
# Please enter your Username: Lisa
# Hello, Lisa
